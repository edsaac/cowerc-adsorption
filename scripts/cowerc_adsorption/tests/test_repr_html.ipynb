# %%
from cowerc_adsorption import PhysicalParams

# %%
p = PhysicalParams(
    L=3.0,
    v=9.65,
    n=0.5,
    sm=9.72e5,
    k_ads=[
        4.706e01,
        1.738e01,
        1.584e01,
        1.488e01,
        2.028e01,
        3.977e01,
    ],
    k_des=[
        1.189e-01,
        1.091e-02,
        3.926e-03,
        2.693e-03,
        1.523e-03,
        2.326e-03,
    ],
    C_0=[1, 2, 3, 4, 5, 6],
)

display(p)
# Out:
# PhysicalParams(L=3.0, v=9.65, n=0.5, sm=972000.0, k_ads=array([47.06, 17.38, 15.84, 14.88, 20.28, 39.77]), k_des=array([0.1189  , 0.01091 , 0.003926, 0.002693, 0.001523, 0.002326]), C_0=array([1, 2, 3, 4, 5, 6]))

# %%
p = PhysicalParams(
    L=3.0,
    v=9.65,
    n=0.5,
    sm=9.72e5,
    k_ads=[
        4.706e01,
    ],
    k_des=[
        1.189e-01,
    ],
    C_0=[2],
)

display(p)
# Out:
# PhysicalParams(L=3.0, v=9.65, n=0.5, sm=972000.0, k_ads=array([47.06]), k_des=array([0.1189]), C_0=array([2]))
